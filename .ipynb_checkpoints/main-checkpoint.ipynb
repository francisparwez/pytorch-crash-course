# %%
a = 10

# %%
print(a)
# Out:
# 10

# %%
a += 5
a
# Out:
# 15

# %%
import torch

# %%
torch.cuda.is_available()
# Out:
# True

# %%
torch.cuda.device_count()
# Out:
# 1

# %%
torch.cuda.get_device_name(0)
# Out:
# 'NVIDIA GeForce RTX 4050 Laptop GPU'

# %%
torch.cuda.device(0)

# %% [markdown]
# ### Tensors

# %%
import numpy as np

# %%
arr = np.array([[1, 2, 3], [4, 5, 6]])
arr
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
tensor = torch.Tensor([[1, 2, 3], [4, 5, 6]])
tensor
# Out:
# tensor([[1., 2., 3.],
#         [4., 5., 6.]])

# %%
arr * 5
# Out:
# array([[ 5, 10, 15],
#        [20, 25, 30]])

# %%
tensor * 5
# Out:
# tensor([[ 5., 10., 15.],
#         [20., 25., 30.]])

# %%
arr.sum()
# Out:
# np.int64(21)

# %%
tensor.sum()
# Out:
# tensor(21.)

# %%
tensor = torch.from_numpy(arr)
tensor
# Out:
# tensor([[1, 2, 3],
#         [4, 5, 6]])

# %%
np.ones((2, 4))
# Out:
# array([[1., 1., 1., 1.],
#        [1., 1., 1., 1.]])

# %%
torch.ones((2, 4))
# Out:
# tensor([[1., 1., 1., 1.],
#         [1., 1., 1., 1.]])

# %%
np.random.random((2, 4))
# Out:
# array([[0.06091837, 0.53996428, 0.40155578, 0.403773  ],
#        [0.43925004, 0.72282813, 0.2363982 , 0.44385836]])

# %%
torch.rand((2, 4))
# Out:
# tensor([[0.7111, 0.0737, 0.7602, 0.5974],
#         [0.2440, 0.0243, 0.9959, 0.4842]])

# %%
arr.shape
# Out:
# (2, 3)

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
arr.device
# Out:
# 'cpu'

# %%
tensor.shape
# Out:
# torch.Size([2, 3])

# %%
tensor.dtype
# Out:
# torch.int64

# %%
tensor.device
# Out:
# device(type='cpu')

# %%
# arr.to_device('cuda)
# ERROR:
#   Cell In[27], line 1
#     arr.to_device('cuda)
#                   ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
tensor.to('cuda')
# Out:
# tensor([[1, 2, 3],
#         [4, 5, 6]], device='cuda:0')

# %%
tensor = tensor.to('cuda')

# %%
tensor.sum()
# Out:
# tensor(21, device='cuda:0')

# %%
# tensor.numpy()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 tensor.numpy()

# TypeError: can't convert cuda:0 device type tensor to numpy. Use Tensor.cpu() to copy the tensor to host memory first.
tensor.cpu().numpy()
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# tensor.to(device)
